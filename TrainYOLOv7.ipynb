# %%
import os
import sys

# %%
# %cd yolov7
# !python3 train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 100 --data "helmet_data/data.yaml" --weights 'weights/yolov7-tiny.pt' --device 6
# Out:
# /DATA/kumar156/YOLO-v7/yolov7
# YOLOR 🚀 2022-9-10 torch 1.10.1+cu102 CUDA:6 (GeForce GTX 1080 Ti, 11178.5MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='helmet_data/data.yaml', device='6', entity=None, epochs=5, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp7', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='weights/yolov7-tiny.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python3 detect.py --weights runs/train/exp/weights/best.pt --conf 0.2 --source helmet_data/test
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.2, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='Number-plate/test', update=False, view_img=False, weights=['runs/train/exp/weights/best.pt'])
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.10.1+cu102 CUDA:0 (GeForce GTX 1080 Ti, 11178.5MB)
#                                              CUDA:1 (GeForce GTX 1080 Ti, 11178.5MB)
#                                              CUDA:2 (GeForce GTX 1080 Ti, 11178.5MB)
#                                              CUDA:3 (GeForce GTX 1080 Ti, 11178.5MB)
#                                              CUDA:4 (GeForce GTX 1080 Ti, 11178.5MB)
#                                              CUDA:5 (GeForce GTX 1080 Ti, 11178.5MB)
#                                              CUDA:6 (GeForce GTX 1080 Ti, 11178.5MB)
# ...
